# %% [markdown]
# <a href="https://colab.research.google.com/github/Mobeenahmedmehr/Mobeen_Ahmed/blob/main/gemini_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GEMINI_API_KEY=userdata.get('GOOGLE_API_KEY')

# %%
import google.generativeai as genai

# %%
genai.configure(api_key = GEMINI_API_KEY)

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
import PIL.Image as img
image = img.open("images.jpg")
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x708>

# %%
prompt = "explain this image in detail"

# %%
response = model.generate_content([image,prompt])
print(response.text)
# Out:
# That's promotional art for the *Tokyo Revengers: Christmas Showdown* anime movie.
#
#
# Here's a breakdown of the image:
#
# * **Central Focus:** The image is dominated by a large group of characters, predominantly young men, styled in a modern, slightly rebellious fashion. Many wear jackets, and their hairstyles are varied and often stylized.  The central figures are a blond-haired boy in a dark jacket with a determined expression and a fist raised; and several figures surrounding him in various fighting poses.
#
# * **Characters:** The characters appear to be members of rival gangs or factions, based on their attire and expressions. They exhibit a wide range of facial features and hairstyles, reflecting individual personalities.  Some characters are clearly more prominent than others.
#
# ...
